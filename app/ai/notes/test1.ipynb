# %%
from paddleocr import PaddleOCR
from PIL import Image

# 이미지 경로 설정
img_path = "../../test/images/realtest.jpg"

# 한국어로 PaddleOCR 초기화
ocr = PaddleOCR(use_angle_cls=True, lang='korean')

# 이미지에서 텍스트 인식
result = ocr.ocr(img_path, cls=True)

# 이미지 열기
image = Image.open(img_path).convert('RGB')

for line in result:
    for word in line:
        print(word[1])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from paddleocr import PaddleOCR
#       2 from PIL import Image
#       4 # 이미지 경로 설정
#
# File c:\Users\lms99\anaconda3\envs\cuda11.7\lib\site-packages\paddleocr\__init__.py:14
#       1 # Copyright (c) 2020 PaddlePaddle Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
# ---> 14 from .paddleocr import *
#      16 __version__ = paddleocr.VERSION
#      17 __all__ = [
#      18     'PaddleOCR', 'PPStructure', 'draw_ocr', 'draw_structure_result',
#      19     'save_structure_res', 'download_with_progressbar', 'sorted_layout_boxes',
#      20     'convert_info_docx', 'to_excel'
#      21 ]
#
# File c:\Users\lms99\anaconda3\envs\cuda11.7\lib\site-packages\paddleocr\paddleocr.py:21
#      17 import importlib
#      19 __dir__ = os.path.dirname(__file__)
# ---> 21 import paddle
#      23 sys.path.append(os.path.join(__dir__, ''))
#      25 import cv2
#
# File c:\Users\lms99\anaconda3\envs\cuda11.7\lib\site-packages\paddle\__init__.py:28
#      21     sys.stderr.write(
#      22         '''Warning with import paddle: you should not
#      23      import paddle from the source directory; please install paddlepaddle*.whl firstly.'''
#      24     )
#      26 # NOTE(SigureMo): We should place the import of base.core before other modules,
#      27 # because there are some initialization codes in base/core/__init__.py.
# ---> 28 from .base import core  # noqa: F401
#      29 from .batch import batch
#      31 # Do the *DUPLICATED* monkey-patch for the tensor object.
#      32 # We need remove the duplicated code here once we fix
#      33 # the illogical implement in the monkey-patch methods later.
#
# File c:\Users\lms99\anaconda3\envs\cuda11.7\lib\site-packages\paddle\base\__init__.py:77
#      74 from . import data_feed_desc
#      75 from .data_feed_desc import DataFeedDesc
# ---> 77 from . import dataset
#      78 from .dataset import (
#      79     DatasetFactory,
#      80     InMemoryDataset,
#      81 )
#      83 from . import trainer_desc
#
# File c:\Users\lms99\anaconda3\envs\cuda11.7\lib\site-packages\paddle\base\dataset.py:20
#      16 from google.protobuf import text_format
#      18 from paddle.base.proto import data_feed_pb2
# ---> 20 from ..utils import deprecated
#      21 from . import core
#      23 __all__ = []
#
# File c:\Users\lms99\anaconda3\envs\cuda11.7\lib\site-packages\paddle\utils\__init__.py:16
#       1 # Copyright (c) 2016 PaddlePaddle Authors. All Rights Reserved
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 from ..base.framework import require_version  # noqa: F401
# ---> 16 from . import (  # noqa: F401
#      17     cpp_extension,
#      18     dlpack,
#      19     download,
#      20     image_util,
#      21     layers_utils,
#      22     unique_name,
#      23 )
#      24 from .deprecated import deprecated
#      25 from .install_check import run_check
#
# File c:\Users\lms99\anaconda3\envs\cuda11.7\lib\site-packages\paddle\utils\image_util.py:18
#      15 from io import StringIO
#      17 import numpy as np
# ---> 18 from PIL import Image
#      20 __all__ = []
#      23 def resize_image(img, target_size):
#
# File c:\Users\lms99\anaconda3\envs\cuda11.7\lib\site-packages\PIL\Image.py:84
#      75 MAX_IMAGE_PIXELS = int(1024 * 1024 * 1024 // 4 // 3)
#      78 try:
#      79     # If the _imaging C module is not present, Pillow will not load.
#      80     # Note that other modules should not refer to _imaging directly;
#      81     # import Image and use the Image.core variable instead.
#      82     # Also note that Image.core is not a publicly documented interface,
#      83     # and should be considered private and subject to change.
# ---> 84     from . import _imaging as core
#      86     if __version__ != getattr(core, "PILLOW_VERSION", None):
#      87         msg = (
#      88             "The _imaging extension was built for another version of Pillow or PIL:\n"
#      89             f"Core version: {getattr(core, 'PILLOW_VERSION', None)}\n"
#      90             f"Pillow version: {__version__}"
#      91         )
#
# ImportError: DLL load failed while importing _imaging: 지정된 모듈을 찾을 수 없습니다.
